# %%
input= "//*[@id=\"company_identity\"]/div[1]/div[" 
input2="]/span"

for i in range(1,11):
  out=input+str(i)+input2
  print(out)
# Out:
# //*[@id="company_identity"]/div[1]/div[1]/span
# //*[@id="company_identity"]/div[1]/div[2]/span
# //*[@id="company_identity"]/div[1]/div[3]/span
# //*[@id="company_identity"]/div[1]/div[4]/span
# //*[@id="company_identity"]/div[1]/div[5]/span
# //*[@id="company_identity"]/div[1]/div[6]/span
# //*[@id="company_identity"]/div[1]/div[7]/span
# //*[@id="company_identity"]/div[1]/div[8]/span
# //*[@id="company_identity"]/div[1]/div[9]/span
# //*[@id="company_identity"]/div[1]/div[10]/span

# %%
from random import seed
from random import random
# seed random number generator


information={0:[], 1:[], 2:[], 3:[], 4:[], 5:[], 6: [], 7: [], 8:[]}

seed(1)
# generate some random numbers

#logica modifico xpath

for i in range (0, 20):
  trade_present=False
  
  x=random()

  if x>0.5:
    trade_present=True
    upper=8
    print('dd')
  else:
    upper=7
    information[8].append('not present')
  information[0].append(i)  #id progressivo
    #per ogni pagina USA
  for j in range(1,upper+1):
      
      
      if j==1:
        x_path=input+str(j)+input2
        information[j].append(x_path)
      else:
        if trade_present==True:
          
          if j==2:
            key=8
            x_path=input+str(j)+input2
            information[key].append(x_path)
          else:
              key=j-1
              x_path=input+str(j)+input2
              information[key].append(x_path)
            
        
          
        else:
          key=j
          x_path=input+str(j)+input2
          information[key].append(x_path)
          
        
       
        
      
for k in information:
  print(k, len(information[k]))
# Out:
# dd
# dd
# dd
# dd
# dd
# dd
# dd
# dd
# dd
# 0 20
# 1 20
# 2 20
# 3 20
# 4 20
# 5 20
# 6 20
# 7 20
# 8 20

# %%
import pandas as pd

# %%
df=pd.DataFrame(information)

display(df)
# Out:
#      0                                               1  \
# 0    0  //*[@id="company_identity"]/div[1]/div[1]/span
# 1    1  //*[@id="company_identity"]/div[1]/div[1]/span
# 2    2  //*[@id="company_identity"]/div[1]/div[1]/span
# 3    3  //*[@id="company_identity"]/div[1]/div[1]/span
# 4    4  //*[@id="company_identity"]/div[1]/div[1]/span
# 5    5  //*[@id="company_identity"]/div[1]/div[1]/span
# 6    6  //*[@id="company_identity"]/div[1]/div[1]/span
# 7    7  //*[@id="company_identity"]/div[1]/div[1]/span
# 8    8  //*[@id="company_identity"]/div[1]/div[1]/span
# 9    9  //*[@id="company_identity"]/div[1]/div[1]/span
# 10  10  //*[@id="company_identity"]/div[1]/div[1]/span
# 11  11  //*[@id="company_identity"]/div[1]/div[1]/span
# 12  12  //*[@id="company_identity"]/div[1]/div[1]/span
# 13  13  //*[@id="company_identity"]/div[1]/div[1]/span
# 14  14  //*[@id="company_identity"]/div[1]/div[1]/span
# 15  15  //*[@id="company_identity"]/div[1]/div[1]/span
# ...
